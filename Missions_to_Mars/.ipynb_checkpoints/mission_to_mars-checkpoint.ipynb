# %%
# Dependencies
from bs4 import BeautifulSoup
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

import pandas as pd
import time

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Driver [C:\Users\pilar\.wdm\drivers\chromedriver\win32\89.0.4389.23\chromedriver.exe] found in cache

# %%
# Create BeautifulSoup object; parse with 'html.parser'
url = 'https://redplanetscience.com/'
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Print formatted version of the soup
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
#   <link href="css/font.css" rel="stylesheet" type="text/css"/>
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
#   <title>
#    News - Mars Exploration Program
#   </title>
#  </head>
#  <body>
#   <div class="col-md-12">
#    <div class="row">
#     <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#      <div class="container-fluid">
#       <a class="navbar-brand" href="#">
# ...

# %%
# Find the titles and their descriptions
news = soup.find_all('div', class_='list_text')

# %%
news
# Out:
# [<div class="list_text">
#  <div class="list_date">April 10, 2021</div>
#  <div class="content_title">NASA's Mars 2020 Rover Closer to Getting Its Name</div>
#  <div class="article_teaser_body">155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.</div>
#  </div>,
#  <div class="list_text">
#  <div class="list_date">April 9, 2021</div>
#  <div class="content_title">Join NASA for the Launch of the Mars 2020 Perseverance Rover</div>
#  <div class="article_teaser_body">No matter where you live, choose from a menu of activities to join NASA as we "Countdown to Mars" and launch the Perseverance rover to the Red Planet.</div>
#  </div>,
#  <div class="list_text">
#  <div class="list_date">April 6, 2021</div>
#  <div class="content_title">NASA's Perseverance Rover Will Look at Mars Through These 'Eyes'</div>
# ...

# %%
# Get all the titles and their paragraphs from the site
news_df = pd.DataFrame()

for new in news:
    # Error handling
    try:
        # Identify and return title
        title = new.find('div', class_='content_title').text
        # Identify and return the paragraph of the title
        paragraph = new.find('div', class_='article_teaser_body').text
        # Identify and return the date of the news
        date = new.find('div', class_='list_date').text
        # Print results only if title, price, and link are available
        if (title and paragraph):
            thisdict = {
                "news_title": title,
                "news_p": paragraph,
                "date": date
            }
            news_df = news_df.append(thisdict, ignore_index = True)
    except AttributeError as e:
        print(e)

# %%
# Print the dataframe that contains all the news titles, description and published dates.
news_df
# Out:
#               date                                             news_p  \
# 0   April 10, 2021  155 students from across the U.S. have been ch...
# 1    April 9, 2021  No matter where you live, choose from a menu o...
# 2    April 6, 2021  A pair of zoomable cameras will help scientist...
# 3   March 29, 2021  A letter from NASA was presented to the mayor ...
# 4   March 27, 2021  NASA's Mars InSight mission honored one of the...
# 5   March 27, 2021  Jim Bridenstine addresses NASA's ambitious pla...
# 6   March 24, 2021  In time-lapse video, bunny-suited engineers re...
# 7   March 24, 2021  Stacking spacecraft components on top of each ...
# 8   March 20, 2021  The pair of briefcase-sized satellites made hi...
# 9   March 20, 2021  The clean room at NASA's Jet Propulsion Labora...
# 10  March 18, 2021  A crisply rendered web application can show yo...
# 11  March 16, 2021  Engineers have a plan for pushing down on the ...
# ...

# %%
# Get the latest title and description
news_title = news_df['news_title'][0]
news_p = news_df['news_p'][0]
print(news_title)
print(news_p)
# Out:
# NASA's Mars 2020 Rover Closer to Getting Its Name
# 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.

# %%
# Part 2: JPL Mars Space Images
#Visit url: https://spaceimages-mars.com/
url = "https://spaceimages-mars.com/"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
#Get the full size featured image
relative_image_path = soup.find('img', class_='headerimage fade-in').get('src')
featured_image_url = url + relative_image_path
print(featured_image_url)
# Out:
# https://spaceimages-mars.com/image/featured/mars1.jpg

# %%
# Part 3: Mars Facts
#Visit url: https://galaxyfacts-mars.com/
url = "https://galaxyfacts-mars.com/"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
#Get the table information
mars_df = pd.DataFrame()
mars_table = soup.find_all('table')[0]
rows = mars_table.find_all('tr')
for row in rows:
    values = row.find_all('td')
    thisdict = {
                "Description": row.find('th').text.strip(),
                "MARS": values[0].text.strip(),
                "EARTH": values[1].text.strip()
            }
    mars_df = mars_df.append(thisdict, ignore_index = True)

# %%
# Print the dataframe
mars_df
# Out:
#                Description            EARTH             MARS
# 0  Mars - Earth Comparison            Earth             Mars
# 1                Diameter:        12,742 km         6,779 km
# 2                    Mass:  5.97 × 10^24 kg  6.39 × 10^23 kg
# 3                   Moons:                1                2
# 4       Distance from Sun:   149,598,262 km   227,943,824 km
# 5          Length of Year:      365.24 days   687 Earth days
# 6             Temperature:      -88 to 58°C     -87 to -5 °C

# %%
# convert the dataframe to html
html_table =  mars_df.to_html(classes='table table-striped', header = True, index=False)
html_table
# Out:
# '<table border="1" class="dataframe table table-striped">\n  <thead>\n    <tr style="text-align: right;">\n      <th>Description</th>\n      <th>EARTH</th>\n      <th>MARS</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>Mars - Earth Comparison</td>\n      <td>Earth</td>\n      <td>Mars</td>\n    </tr>\n    <tr>\n      <td>Diameter:</td>\n      <td>12,742 km</td>\n      <td>6,779 km</td>\n    </tr>\n    <tr>\n      <td>Mass:</td>\n      <td>5.97 × 10^24 kg</td>\n      <td>6.39 × 10^23 kg</td>\n    </tr>\n    <tr>\n      <td>Moons:</td>\n      <td>1</td>\n      <td>2</td>\n    </tr>\n    <tr>\n      <td>Distance from Sun:</td>\n      <td>149,598,262 km</td>\n      <td>227,943,824 km</td>\n    </tr>\n    <tr>\n      <td>Length of Year:</td>\n      <td>365.24 days</td>\n      <td>687 Earth days</td>\n    </tr>\n    <tr>\n      <td>Temperature:</td>\n      <td>-88 to 58°C</td>\n      <td>-87 to -5 °C</td>\n    </tr>\n  </tbody>\n</table>'

# %%
# Part 4: Mars Hemispheres
url = "https://marshemispheres.com/"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Get the list of links
link_section = soup.find('div', class_='collapsible results')
links = link_section.find_all('div', class_='item')
hemisphere_image_urls = []

for link in links:
    link_url= link.find('a', class_='itemLink product-item').get('href')
    img_name = ' '.join(link.find('a', class_='itemLink product-item').find('img').get('alt').split()[:-2])
    browser.visit(url+link_url)
    link_html = browser.html
    link_soup = BeautifulSoup(link_html, 'html.parser')
    img_url = url + (link_soup.find('img', class_='wide-image').get('src'))
    hemisphere_image_urls.append({
        'title': img_name,
        'img_url':img_url
    })


for x in hemisphere_image_urls:
    print(x)
    print('---------')
# Out:
# {'title': 'Cerberus Hemisphere', 'img_url': 'https://marshemispheres.com/images/f5e372a36edfa389625da6d0cc25d905_cerberus_enhanced.tif_full.jpg'}
# ---------
# {'title': 'Schiaparelli Hemisphere', 'img_url': 'https://marshemispheres.com/images/3778f7b43bbbc89d6e3cfabb3613ba93_schiaparelli_enhanced.tif_full.jpg'}
# ---------
# {'title': 'Syrtis Major Hemisphere', 'img_url': 'https://marshemispheres.com/images/555e6403a6ddd7ba16ddb0e471cadcf7_syrtis_major_enhanced.tif_full.jpg'}
# ---------
# {'title': 'Valles Marineris Hemisphere', 'img_url': 'https://marshemispheres.com/images/b3c7c6c9138f57b4756be9b9c43e3a48_valles_marineris_enhanced.tif_full.jpg'}
# ---------

# %%
browser.quit()
